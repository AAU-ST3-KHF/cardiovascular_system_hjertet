# %% [markdown]
# # EKG fra celler til hjertevektor — 60‑min Øvelse (opdateret)
# **Fag**: Biomedicinsk ingeniørvidenskab (3. semester)
# **Emne**: Fra membranpotentialer til EKG‑afledninger via hjertevektoren
#
# **Læringsmål**:
# - Forklar, hvordan ændringer i enkeltcellers membranpotentiale bidrager til EKG‑signalet.
# - Beskriv hjertevektoren (det kardiale dipolmoment) i frontalplanet.
# - Beregn standardafledningerne I, II, III ud fra hjertevektoren og verificér Einthovens lov.
# - Beregn afledning II ud fra I og III; rekonstruér hjertevektoren ud fra I og II.
# - **Nyt**: Indlæs **målt EKG fra CSV** og plot et **udsnit med 2 RR‑cyklusser**.
#
# _Tidsbudget_: 60 minutter (+10 min valgfri CSV‑arbejdsdel)

# %%
# 0) Opsætning — imports og plotindstillinger
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) Fra enkeltcelle‑membranpotentiale til et EKG‑lignende signal
# **Koncepter**:
#
# - Hver myocytes **transmembranpotentiale** $V_m(t)$ ændrer sig under depolarisering og repolarisering.
# - Når mange celler aktiveres **sekventielt** (en udbredende bølgefront), summerer deres **transmembrane strømme** (tilnærmet relateret til $\mathrm{d}V_m/\mathrm{d}t$) til et **fjernfeltssignal** målt ved elektroder.
# - I en simpel fjernfelts‑tilnærmelse er EKG fra en fiber omtrent proportional med den **vægtede sum af $\mathrm{d}V_m/\mathrm{d}t$** på tværs af celler, skaleret af geometri og afledningsretning.
#
# Vi simulerer: (1) et glat AP, (2) en 1D række celler med konstant udbredelseshastighed, (3) et EKG‑lignende signal som summen af $\mathrm{d}V_m/\mathrm{d}t$.

# %%
# 1.1 Definér et simpelt aktionspotentiale og visualisér
def sigmoid(x, tau):
    return 1.0 / (1.0 + np.exp(-x / tau))

def simpelt_AP(t, t0=0.0, APD=300.0, tau_op=1.5, tau_rep=12.0,
               V_hvile=-85.0, V_top=30.0):
    """
    Glat 'rektangulært' AP: V_hvile -> V_top -> V_hvile
    t i ms. APD ~ varighed af depolariseret fase.
    """
    op = sigmoid(t - t0, tau_op)            # glat depolarisering efter t0
    ned = sigmoid((t0 + APD) - t, tau_rep) # ~1 før APD, ~0 efter APD
    boks = op * ned
    return V_hvile + (V_top - V_hvile) * boks

# Demo: enkelt AP
t = np.linspace(-50, 450, 2000)  # ms
Vm = simpelt_AP(t, t0=0, APD=280, tau_op=2.0, tau_rep=10.0)

ax = plt.subplot(2,1,1)
ax.plot(t, Vm)
ax.set_title('Enkeltcelle‑aktionspotentiale (legetøjsmodel)')
ax.set_xlabel('Tid (ms)')
ax.set_ylabel('V_m (mV)')

# Tidsderivativ (tilnærmet transmembran strømsignatur)
dVm_dt = np.gradient(Vm, t[1] - t[0])
ax = plt.subplot(2,1,2)
ax.plot(t, dVm_dt, color='C1')
ax.set_title('Estimat af transmembran strøm ~ dV_m/dt')
ax.set_xlabel('Tid (ms)')
ax.set_ylabel('dV_m/dt (mV/ms)')
plt.show()

# %%
# 1.2 Udbredelse langs en 1D fiber og et EKG‑lignende signal
N = 200                 # antal celler
dx = 0.1                # mm pr. celle (vilkårligt)
v = 0.6                 # mm/ms ledningshastighed (0.6 mm/ms = 0.6 m/s)
theta_grader = 30.0     # fiber-/hjerteakse‑orientering (frontalplan)

t_ms = np.linspace(0, 350, 2000)  # simuleringstid (ms)
dt = t_ms[1] - t_ms[0]
x = np.arange(N) * dx
t_akt = x / v  # aktiveringstid for hver celle (ms)

def enhedsvektor(grader):
    rad = np.deg2rad(grader)
    return np.array([np.cos(rad), np.sin(rad)])

e_hjerte = enhedsvektor(theta_grader)
afledningsretning_grader = 60.0
e_afl = enhedsvektor(afledningsretning_grader)
orienteringsvægt = float(np.dot(e_afl, e_hjerte))  # i [-1,1]

APD = 280
Vm_alle = np.zeros((len(t_ms), N))
for i in range(N):
    Vm_alle[:, i] = simpelt_AP(t_ms, t0=t_akt[i], APD=APD, tau_op=2.0, tau_rep=10.0)

dVm_dt_alle = np.gradient(Vm_alle, dt, axis=0)
ekg_lign = orienteringsvægt * dVm_dt_alle.sum(axis=1)

fig, axs = plt.subplots(2, 1, figsize=(6, 4), sharex=True)
from matplotlib.axes import Axes
axs: list[Axes]
axs[0].plot(t_ms, Vm_alle[:, 0], label='Celle 0')
axs[0].plot(t_ms, Vm_alle[:, int(N/2)], label=f'Celle {int(N/2)}', alpha=0.8)
axs[0].plot(t_ms, Vm_alle[:, -1], label=f'Celle {N-1}', alpha=0.7)
axs[0].set_ylabel('V_m (mV)')
axs[0].set_title('Udvalgte celler med forsinkelse pga. udbredelse')
axs[0].legend(loc='best')

axs[1].plot(t_ms, ekg_lign, color='C3')
axs[1].set_xlabel('Tid (ms)')
axs[1].set_ylabel('Afledningssignal (arb. enheder)')
axs[1].set_title('EKG-lignende signal fra udbredende aktivering')
plt.tight_layout()
plt.show()

print(f'Orienteringskobling (afledning vs. fiber): {orienteringsvægt:.2f}')
print('OPGAVE A: Ændr v (ledningshastighed) og observer QRS-bredde.')
print('OPGAVE B: Ændr APD og observer ændringer i T-lignende komponent.')
print('OPGAVE C: Sæt afledningsretning tæt på vinkelret på theta_grader og se amplitudefald.')
# Out:
# Orienteringskobling (afledning vs. fiber): 0.87
# OPGAVE A: Ændr v (ledningshastighed) og observer QRS‑bredde.
# OPGAVE B: Ændr APD og observer ændringer i T‑lignende komponent.
# OPGAVE C: Sæt afledningsretning tæt på vinkelret på theta_grader og se amplitudefald.

# %% [markdown]
# ### Phaser
#
# I virkeligheden har vi flere forskellige typer af celler i hjertet, som alle har unikke depolariserings mønstre.
# Hvis vi snakker omkr
# ![image](files/Shapes_of_the_cardiac_action_potential_in_the_heart.jpg)

# %% [markdown]
# ## 2) Hjertevektor og standardafledninger
# **Koncepter**:
#
# - I frontalplanet kan hjertets elektriske aktivitet beskrives som en **tidsvarierende dipolvektor** $\mathbf{p}(t)$.
# - Potentialet ved en elektrode (fjernfelt, homogen torso) er proportionalt med $\mathbf{p}(t) \cdot \hat{\mathbf{r}}_e$.
# - **Standardafledninger** er potentialeforskelle mellem elektroder: I = $\phi(\mathrm{LA})-\phi(\mathrm{RA})$, II = $\phi(\mathrm{LL})-\phi(\mathrm{RA})$, III = $\phi(\mathrm{LL})-\phi(\mathrm{LA})$.
# - **Einthovens lov**: **II = I + III**.
#
# Vi (1) definerer elektrodernes retningsvektorer, (2) beregner I/II/III fra $\mathbf{p}(t)$, (3) verificerer Einthovens lov.

# %%
# 2.1 Elektrodegeometri og beregning af afledninger
def rhat_fra_grader(grader):
    rad = np.deg2rad(grader)
    return np.array([np.cos(rad), np.sin(rad)])

# Pædagogisk (enkel) geometri: RA 0°, LA 180°, LL -90°
rhat_RA = rhat_fra_grader(0.0)
rhat_LA = rhat_fra_grader(180.0)
rhat_LL = rhat_fra_grader(-90.0)

def elektrode_potentiale(p_vec, rhat):
    return float(np.dot(p_vec, rhat))

def afledninger_fra_p(p_vec):
    phi_RA = elektrode_potentiale(p_vec, rhat_RA)
    phi_LA = elektrode_potentiale(p_vec, rhat_LA)
    phi_LL = elektrode_potentiale(p_vec, rhat_LL)
    lead_I   = phi_LA - phi_RA
    lead_II  = phi_LL - phi_RA
    lead_III = phi_LL - phi_LA
    return lead_I, lead_II, lead_III

# %%
# 2.2 Syntetisk hjertevektor‑bane p(t) og resulterende afledninger
T_total = 0.8  # sekunder pr. slag
fs_sim = 1000  # Hz
tt = np.arange(0, T_total, 1/fs_sim)

def hjertevektor_bane(t):
    tP_on, tP_off     = 0.10, 0.16
    tQRS_on, tQRS_off = 0.16, 0.22
    tT_on, tT_off     = 0.28, 0.44
    px = np.zeros_like(t)
    py = np.zeros_like(t)
    # P‑bølge
    idx = (t>=tP_on) & (t<=tP_off)
    vP = np.deg2rad(-20.0)
    aP = 0.2 * np.sin(np.pi*(t[idx]-tP_on)/(tP_off - tP_on))
    px[idx] += aP * np.cos(vP)
    py[idx] += aP * np.sin(vP)
    # QRS
    idx = (t>=tQRS_on) & (t<=tQRS_off)
    vQRS = np.deg2rad(30.0)
    aQRS = 1.0 * np.sin(np.pi*(t[idx]-tQRS_on)/(tQRS_off - tQRS_on))
    px[idx] += aQRS * np.cos(vQRS)
    py[idx] += aQRS * np.sin(vQRS)
    # T‑bølge
    idx = (t>=tT_on) & (t<=tT_off)
    vT = np.deg2rad(10.0)
    aT = 0.4 * np.sin(np.pi*(t[idx]-tT_on)/(tT_off - tT_on))
    px[idx] += aT * np.cos(vT)
    py[idx] += aT * np.sin(vT)
    return np.stack([px, py], axis=1)

p = hjertevektor_bane(tt)
afled = np.array([afledninger_fra_p(pi) for pi in p])
lead_I, lead_II, lead_III = afled[:,0], afled[:,1], afled[:,2]

fig, axs = plt.subplots(2, 1, figsize=(6,5))
axs[0].plot(p[:,0], p[:,1], color='k')
axs[0].axhline(0, color='gray', lw=0.5); axs[0].axvline(0, color='gray', lw=0.5)
axs[0].set_aspect('equal', 'box')
axs[0].set_title('Hjertevektor‑bane p(t) i frontalplanet')
axs[0].set_xlabel('p_x'); axs[0].set_ylabel('p_y')
axs[1].plot(tt*1000, lead_I, label='Afledning I')
axs[1].plot(tt*1000, lead_II, label='Afledning II')
axs[1].plot(tt*1000, lead_III, label='Afledning III')
axs[1].set_xlabel('Tid (ms)')
axs[1].set_ylabel('Potentiale (a.e.)')
axs[1].set_title('Standardafledninger ud fra hjertevektor')
axs[1].legend()
plt.tight_layout(); plt.show()
print('OPGAVE D: Ændr vQRS/vT/vP (retninger) og se amplitudefordeling i afledningerne.')
print('OPGAVE E: Ændr størrelser (aQRS/aT/aP) og se skalering i alle afledninger.')
# Out:
# OPGAVE D: Ændr vQRS/vT/vP (retninger) og se amplitudefordeling i afledningerne.
# OPGAVE E: Ændr størrelser (aQRS/aT/aP) og se skalering i alle afledninger.

# %%
# 2.3 Verificér Einthovens lov og beregn II ud fra I og III
einthoven_res = lead_II - (lead_I + lead_III)
fig, ax = plt.subplots()
ax.plot(tt*1000, einthoven_res)
ax.set_title('Einthoven‑residual: II − (I + III)')
ax.set_xlabel('Tid (ms)')
ax.set_ylabel('Residual (a.e.)')
plt.show()
print(f'Residual middel: {einthoven_res.mean():.3e}, max |residual|: {np.max(np.abs(einthoven_res)):.3e}')

def leadII_fra_I_og_III(lead_I, lead_III):
    """Returnér Afledning II vha. Einthovens lov.
    OPGAVE F: Forklar i tekst, hvorfor det er korrekt.
    """
    return lead_I + lead_III  # forventet løsning

leadII_rekon = leadII_fra_I_og_III(lead_I, lead_III)
fig, ax = plt.subplots()
ax.plot(tt*1000, lead_II, label='Afledning II (direkte)', lw=2)
ax.plot(tt*1000, leadII_rekon, '--', label='Afledning II (fra I + III)')
ax.set_xlabel('Tid (ms)'); ax.set_ylabel('Potentiale (a.e.)')
ax.set_title('Rekonstruktion af Afledning II via Einthovens lov')
ax.legend(); plt.show()

rekon_fejl = lead_II - leadII_rekon
print(f'Rekonstruktionsfejl — middel: {rekon_fejl.mean():.3e}, max |fejl|: {np.max(np.abs(rekon_fejl)):.3e}')
# Out:
# Residual middel: 7.199e-19, max |residual|: 2.220e-16
# Rekonstruktionsfejl — middel: 7.199e-19, max |fejl|: 2.220e-16

# %% [markdown]
# ## 3) Rekonstruér hjertevektor p fra Afledning I & II
# **Idé**: Lad $\mathbf{B}$ have rækker $\mathbf{B}_1^\top = (\hat r_{LA}-\hat r_{RA})$ og $\mathbf{B}_2^\top = (\hat r_{LL}-\hat r_{RA})$.
# Så gælder $[I, II]^\top = \mathbf{B}\,\mathbf{p}$. Hvis $\mathbf{B}$ er invertibel: $\mathbf{p} = \mathbf{B}^{-1}[I, II]^\top$.

# %%
# 3.1 Implementér rekonstruktion af p(t) fra I og II
B1 = rhat_LA - rhat_RA
B2 = rhat_LL - rhat_RA
B = np.vstack([B1, B2])
print('Determinant for B:', np.linalg.det(B))

def rekonstruer_p_fra_I_II(serie_I, serie_II, B):
    Binv = np.linalg.inv(B)
    p_rec = []
    for I, II in zip(serie_I, serie_II):
        V = np.array([I, II])
        p = Binv @ V
        p_rec.append(p)
    return np.array(p_rec)

p_rec = rekonstruer_p_fra_I_II(lead_I, lead_II, B)
fig, axs = plt.subplots(1, 2, figsize=(8,4))
axs[0].plot(p[:,0], p[:,1], label='Sand p(t)')
axs[0].set_aspect('equal', 'box'); axs[0].set_title('Sand p(t)')
axs[0].axhline(0,color='gray',lw=0.5); axs[0].axvline(0,color='gray',lw=0.5)
axs[0].set_xlabel('p_x'); axs[0].set_ylabel('p_y')
axs[1].plot(p_rec[:,0], p_rec[:,1], label='Rekonstrueret p(t)', color='C2')
axs[1].set_aspect('equal', 'box'); axs[1].set_title('Rekonstrueret p(t)')
axs[1].axhline(0,color='gray',lw=0.5); axs[1].axvline(0,color='gray',lw=0.5)
axs[1].set_xlabel('p_x'); axs[1].set_ylabel('p_y')
plt.tight_layout(); plt.show()

fejl = np.linalg.norm(p - p_rec, axis=1)
print(f'Middel |fejl|: {fejl.mean():.3e}, max |fejl|: {fejl.max():.3e}')

# VALGFRIT: robusthed ift. støj
rng = np.random.default_rng(42)
støjniveau = 0.02
I_støj = lead_I + støjniveau * rng.standard_normal(len(lead_I))
II_støj = lead_II + støjniveau * rng.standard_normal(len(lead_II))
p_rec_støj = rekonstruer_p_fra_I_II(I_støj, II_støj, B)
fejl_støj = np.linalg.norm(p - p_rec_støj, axis=1)
print(f'[Med støj] Middel |fejl|: {fejl_støj.mean():.3e}, max |fejl|: {fejl_støj.max():.3e}')
# Out:
# Determinant for B: 2.0
# Middel |fejl|: 7.505e-18, max |fejl|: 2.483e-16
# [Med støj] Middel |fejl|: 2.090e-02, max |fejl|: 8.174e-02

# %% [markdown]
# ## 4) Opsamling / Refleksion
# 1. **Celler → EKG**: Hvilke aspekter af AP‑formen (fx APD) og udbredelseshastigheden påvirkede signalet mest?
# 2. **Hjertevektor → Afledninger**: Hvordan ændrer retningen af $\mathbf{p}$ de relative amplituder i I, II, III?
# 3. **Einthovens lov**: Hvorfor gælder II = I + III (hint: afledninger er differenser af elektrodepotentialer)?
# 4. **Invers mapping**: Hvilke antagelser ligger bag rekonstruktionen af $\mathbf{p}$ fra I & II (plan dipol, stationær geometri osv.)?
#
# **Valgfrie udvidelser**
# - Udregn aVR, aVL, aVF vha. Wilsons centrale terminal $\mathrm{WCT} = (\phi_{RA}+\phi_{LA}+\phi_{LL})/3$.
# - Bestem middel QRS‑akse i frontalplanet ud fra limb‑afledninger.

# %%
# Valgfrit: augmented limb‑afledninger (aVR, aVL, aVF)
def augmented_afledninger_fra_p(p_vec):
    phi_RA = elektrode_potentiale(p_vec, rhat_RA)
    phi_LA = elektrode_potentiale(p_vec, rhat_LA)
    phi_LL = elektrode_potentiale(p_vec, rhat_LL)
    WCT = (phi_RA + phi_LA + phi_LL)/3.0
    aVR = phi_RA - WCT
    aVL = phi_LA - WCT
    aVF = phi_LL - WCT
    return aVR, aVL, aVF

aVR, aVL, aVF = np.array([augmented_afledninger_fra_p(pi) for pi in p]).T
fig, ax = plt.subplots()
ax.plot(tt*1000, aVR, label='aVR')
ax.plot(tt*1000, aVL, label='aVL')
ax.plot(tt*1000, aVF, label='aVF')
ax.set_xlabel('Tid (ms)')
ax.set_ylabel('Potentiale (a.e.)')
ax.set_title('Augmenterede limb‑afledninger (valgfrit)')
ax.legend(); plt.show()

# %% [markdown]
# ## 5) Arbejdsdel: Plot **målt EKG** fra CSV og vælg **2 RR‑cyklusser**
# I denne del bruger vi en fil `0001.csv` (kolonner: `time_s, ECG1, ECG2, NIBP`).
# Målet er at: (a) indlæse ~10 s data, (b) vælge **start** og **stop** for præcis **2 RR‑cyklusser**, (c) plotte udsnittet pænt.

# %%
# 5.1 Indlæs CSV og beregn samplingfrekvens
from pathlib import Path


csv_path = 'files/autonomic-aging-cardiovascular/0001.csv'  # tilpas sti hvis nødvendigt
df = pd.read_csv(Path(csv_path))
expected = {'time_s', 'ECG1', 'ECG2', 'NIBP'}
missing = expected - set(df.columns)
if missing:
    raise ValueError(f'Manglende kolonner i CSV: {missing}. Fandt: {list(df.columns)}')
df = df.sort_values('time_s').drop_duplicates(subset=['time_s']).reset_index(drop=True)
t_csv = df['time_s'].to_numpy()
if len(t_csv) < 2:
    raise ValueError('For få samples i CSV til at udlede fs.')
dt = np.diff(t_csv)
fs_csv = 1.0 / np.median(dt)
varighed = float(t_csv[-1] - t_csv[0])
print(f'CSV: Estimeret fs = {fs_csv:.2f} Hz | Varighed = {varighed:.2f} s | N = {len(df)}')
df.head()
# Out:
# CSV: Estimeret fs = 100.00 Hz | Varighed = 9.99 s | N = 1000
#    time_s      ECG1      ECG2        NIBP
# 0    0.00  0.186327 -0.054055  113.253152
# 1    0.01  0.197330 -0.028579  113.084352
# 2    0.02  0.200241 -0.053481  112.904868
# 3    0.03  0.193263 -0.037275  112.692265
# 4    0.04  0.224603 -0.041327  112.423040

# %%
# 5.2 Hjælpefunktioner: baseline-korrektion og plot af udsnit
def moving_average(x, n):
    n = max(1, int(n))
    if n <= 1:
        return x
    k = np.ones(n)/n
    return np.convolve(x, k, mode='same')

def baseline_correct(ecg, fs, baseline_sec=0.7, smooth_sec=0.012):
    n_base = max(1, int(round(baseline_sec * fs)))
    n_smooth = max(1, int(round(smooth_sec * fs)))
    base = moving_average(ecg, n_base)
    ecg_hp = ecg - base
    ecg_view = moving_average(ecg_hp, n_smooth)
    return ecg_view

def plot_ecg_segment(df_seg, use_baseline_correction=True, fs=None, title='EKG-udsnit (CSV)'):
    t = df_seg['time_s'].to_numpy()
    e1 = df_seg['ECG1'].to_numpy()
    e2 = df_seg['ECG2'].to_numpy()
    if use_baseline_correction and fs is not None:
        e1v = baseline_correct(e1, fs)
        e2v = baseline_correct(e2, fs)
        y1, y2 = e1v, e2v
        ylabel = 'Amplitude (korrigeret a.e.)'
    else:
        y1, y2 = e1, e2
        ylabel = 'Amplitude (a.e.)'
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(t, y1, label='ECG1', lw=1.0)
    ax.plot(t, y2, label='ECG2', lw=1.0, alpha=0.9)
    ax.set_xlabel('Tid (s)')
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    ax.legend(loc='upper right')
    plt.tight_layout(); plt.show()

# %%
# 5.3 Fuld længde plot (overblik)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df['time_s'], df['ECG1'], lw=0.9, label='ECG1')
ax.plot(df['time_s'], df['ECG2'], lw=0.9, alpha=0.85, label='ECG2')
ax.set_title('EKG — fuld længde (fra CSV)')
ax.set_xlabel('Tid (s)'); ax.set_ylabel('Amplitude (a.e.)')
ax.legend(); plt.tight_layout(); plt.show()

# %%
# 5.4 Vælg start/stop for præcis 2 RR‑cyklusser og plot udsnittet
# >>> UDFYLD HER: tider i sekunder (brug fuld længde-plottet som guide)
t_start = 1.00   # <-- Angiv starttid (s)
t_stop  = 3.10   # <-- Angiv sluttid (s) så udsnittet dækker PRÆCIS 2 RR

mask = (df['time_s'] >= t_start) & (df['time_s'] <= t_stop)
df_seg = df.loc[mask].copy()
if df_seg.empty:
    raise ValueError('Udsnittet er tomt. Tjek t_start/t_stop.')
start_t = float(df_seg['time_s'].iloc[0])
stop_t = float(df_seg['time_s'].iloc[-1])
dur_t = stop_t - start_t
print(f'Udsnit: {start_t:.3f}s → {stop_t:.3f}s ({dur_t:.3f}s), N={len(df_seg)}')
plot_ecg_segment(df_seg, use_baseline_correction=True, fs=fs_csv,
                 title=f'CSV: 2 RR‑cyklusser ({t_start:.2f}–{t_stop:.2f} s)')
# Out:
# Udsnit: 1.000s → 3.100s (2.100s), N=211

# %%
# 5.5 Valgfrit: vælg tider ved at klikke i plottet (kræver backend der understøtter ginput)
use_ginput = False  # sæt True for at prøve
if use_ginput:
    fig, ax = plt.subplots(figsize=(10, 3.2))
    ax.plot(df['time_s'], df['ECG1'], lw=0.9)
    ax.set_title('Klik to punkter (start & stop)')
    ax.set_xlabel('Tid (s)'); ax.set_ylabel('Amplitude (a.e.)')
    plt.tight_layout()
    pts = plt.ginput(2, timeout=30)
    plt.close(fig)
    if len(pts) == 2:
        t_start, t_stop = sorted([pts[0][0], pts[1][0]])
        print(f'Valgt: start={t_start:.3f}s, stop={t_stop:.3f}s')
        mask = (df['time_s'] >= t_start) & (df['time_s'] <= t_stop)
        df_seg = df.loc[mask].copy()
        plot_ecg_segment(df_seg, use_baseline_correction=True, fs=fs_csv,
                         title=f'CSV: 2 RR‑cyklusser ({t_start:.2f}–{t_stop:.2f} s)')
    else:
        print('Der blev ikke registreret to klik.')

# %%
# 5.6 Valgfrit: gem udsnittet til ny CSV
save_segment = False  # sæt True hvis du vil gemme
out_name = '0001_segment_2RR.csv'
if save_segment:
    df_seg.to_csv(out_name, index=False)
    print(f'Gemte udsnit til: {out_name} (rækker: {len(df_seg)})')
